# %%
from IPython.display import Markdown, display
# !tree
# Out:
# .
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 1 directory, 6 files

# %%
from openai_config import client,ask_gpt4o

# response = client.chat.completions.create()
response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
display(Markdown(response))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2221269830.py in <cell line: 0>()
# ----> 1 from .openai_config import client,ask_gpt4o
#       2
#       3 # response = client.chat.completions.create()
#       4 response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
#       5 display(Markdown(response))
#
# ImportError: attempted relative import with no known parent package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
