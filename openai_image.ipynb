# %%
# !git clone https://github.com/mogesTesema/Agentic-AI-projects.git
# %cd Agentic-AI-projects
# Out:
# Cloning into 'Agentic-AI-projects'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (50/50), done.
# Receiving objects: 100% (63/63), 82.72 KiB | 1.40 MiB/s, done.
# remote: Total 63 (delta 16), reused 20 (delta 5), pack-reused 0 (from 0)
# Resolving deltas: 100% (16/16), done.
# /content/Agentic-AI-projects/Agentic-AI-projects

# %%
import sys
sys.path.append("content/Agentic-AI-projects")

# %%
from IPython.display import Markdown, display
# !tree
# Out:
# .
# ├── openai_config.py
# ├── openai_image.ipynb
# ├── README.md
# ├── requirements.txt
# └── retrival_models.ipynb
#
# 0 directories, 5 files

# %%
# !pip install -r requirements.txt

# %%
from openai_config import client,ask_gpt4o

# response = client.chat.completions.create()

response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
display(Markdown(response))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipython-input-3146970886.py in <cell line: 0>()
# ----> 1 from openai_config import client,ask_gpt4o
#       2
#       3 # response = client.chat.completions.create()
#       4
#       5 response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
#
# /content/Agentic-AI-projects/Agentic-AI-projects/openai_config.py in <module>
#       8 OPENAI_URL = os.getenv("OPENAI_URL","https://models.inference.ai.azure.com")
#       9
# ---> 10 client = OpenAI(
#      11     base_url=OPENAI_URL,
#      12     api_key=GITHUB_OPENAI_API_KEY
#
# /usr/local/lib/python3.12/dist-packages/openai/_client.py in __init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
# ...
