# %%
from google.colab import userdata
try:
  print(userdata.get('GITHUB_OPENAI_API_KEY'))
  print("Success: Secret found!")
except:
  print("Error: Secret NOT found or access not granted.")
# Out:
# Error: Secret NOT found or access not granted.

# %%
import os

print("GITHUB_OPENAI_API_KEY" in os.environ)
print(os.environ.get("GITHUB_OPENAI_API_KEY"))
# Out:
# False
# None

# %%
# %rm -rf Agentic-AI-projects/

# %%
# %cd ~

# %%
# %ls

# %%
# !git clone https://github.com/mogesTesema/Agentic-AI-projects.git
# %cd Agentic-AI-projects

# %%
import sys
sys.path.append("content/Agentic-AI-projects")

# %%
from IPython.display import Markdown, display
# !tree
# Out:
# .
# ├── openai_config.py
# ├── openai_image.ipynb
# ├── README.md
# ├── requirements.txt
# └── retrival_models.ipynb
#
# 0 directories, 5 files

# %%
# !pip install -r requirements.txt

# %%
from openai_config import client,ask_gpt4o

# response = client.chat.completions.create()

response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
display(Markdown(response))
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipython-input-3146970886.py in <cell line: 0>()
# ----> 1 from openai_config import client,ask_gpt4o
#       2
#       3 # response = client.chat.completions.create()
#       4
#       5 response = ask_gpt4o("how to forget and remove deep love feeling with some girl")
#
# ~/Agentic-AI-projects/openai_config.py in <module>
#      13 if in_colab():
#      14     from google.colab import userdata
# ---> 15     api_key = userdata.get('GITHUB_OPENAI_API_KEY')
#      16     # api_key = os.environ.get("GITHUB_OPENAI_API_KEY")
#      17     if api_key is None:
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# ...

# %%
import sys
print("google.colab" in sys.modules)
# Out:
# True
